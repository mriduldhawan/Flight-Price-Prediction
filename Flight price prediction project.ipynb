# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
train_df = pd.read_excel('Data_Train.xlsx')
test_df = pd.read_excel('Test_set.xlsx')

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
train_df.shape
# Out:
# (10683, 11)

# %%
test_df.shape
# Out:
# (2671, 10)

# %%
big_df = train_df.append(test_df, sort=False)
big_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
big_df.shape
# Out:
# (13354, 11)

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
big_df['Date'] = big_df['Date_of_Journey'].str.split('/').str[0]
big_df['Month'] = big_df['Date_of_Journey'].str.split('/').str[1]
big_df['year'] = big_df['Date_of_Journey'].str.split('/').str[2]

# %%
big_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# 3    05  2019
# 4    03  2019

# %%
big_df['Date']=big_df['Date'].astype(int)
big_df['Month']=big_df['Month'].astype(int)
big_df['year']=big_df['year'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# year                 int32
# dtype: object

# %%
big_df=big_df.drop(['Date_of_Journey'], axis=1)
big_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# 5              SpiceJet   Kolkata    Banglore              CCU → BLR    09:00
# 6           Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    18:55
# 7           Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:00
# 8           Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:55
# 9     Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:25
# 10            Air India     Delhi      Cochin        DEL → BLR → COK    09:45
# 11               IndiGo   Kolkata    Banglore              CCU → BLR    20:20
# 12            Air India   Chennai     Kolkata              MAA → CCU    11:40
# 13          Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    21:10
# 14               IndiGo   Kolkata    Banglore              CCU → BLR    17:15
# 15            Air India     Delhi      Cochin  DEL → AMD → BOM → COK    16:40
# 16             SpiceJet     Delhi      Cochin        DEL → PNQ → COK    08:45
# 17          Jet Airways     Delhi      Cochin        DEL → BOM → COK    14:00
# 18            Air India     Delhi      Cochin  DEL → CCU → BOM → COK    20:15
# 19          Jet Airways     Delhi      Cochin        DEL → BOM → COK    16:00
# 20                GoAir     Delhi      Cochin        DEL → BOM → COK    14:10
# 21            Air India  Banglore   New Delhi        BLR → COK → DEL    22:00
# 22               IndiGo  Banglore       Delhi              BLR → DEL    04:00
# 23               IndiGo  Banglore       Delhi              BLR → DEL    18:55
# 24          Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    18:55
# 25          Jet Airways     Delhi      Cochin  DEL → IDR → BOM → COK    21:25
# 26               IndiGo     Delhi      Cochin        DEL → LKO → COK    21:50
# 27                GoAir     Delhi      Cochin        DEL → BOM → COK    07:00
# 28              Vistara  Banglore       Delhi              BLR → DEL    09:45
# 29              Vistara   Chennai     Kolkata              MAA → CCU    07:05
# ...                 ...       ...         ...                    ...      ...
# 2641  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    14:00
# 2642        Jet Airways     Delhi      Cochin        DEL → BOM → COK    22:50
# 2643          Air India     Delhi      Cochin  DEL → HYD → MAA → COK    09:45
# 2644  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    07:30
# 2645        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    22:55
# 2646        Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    23:05
# 2647          Air India   Kolkata    Banglore  CCU → GAU → DEL → BLR    16:45
# 2648             IndiGo     Delhi      Cochin              DEL → COK    21:05
# 2649           SpiceJet  Banglore       Delhi              BLR → DEL    05:55
# 2650          Air India   Kolkata    Banglore  CCU → IXR → DEL → BLR    05:50
# 2651        Jet Airways   Kolkata    Banglore        CCU → DEL → BLR    09:35
# 2652        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    22:55
# 2653        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    16:30
# 2654          Air India     Delhi      Cochin        DEL → BOM → COK    07:00
# 2655  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:40
# 2656        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    21:10
# 2657  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
# 2658        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2659        Jet Airways     Delhi      Cochin  DEL → BHO → BOM → COK    05:30
# 2660          Air India    Mumbai   Hyderabad  BOM → GOI → PNQ → HYD    16:50
# 2661        Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10
# 2662          Air India    Mumbai   Hyderabad              BOM → HYD    13:55
# 2663              GoAir   Kolkata    Banglore        CCU → BOM → BLR    23:30
# 2664  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    15:15
# 2665           SpiceJet    Mumbai   Hyderabad              BOM → HYD    22:45
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#       Arrival_Time Duration Total_Stops               Additional_Info  \
# 0     01:10 22 Mar   2h 50m    non-stop                       No info
# 1            13:15   7h 25m     2 stops                       No info
# 2     04:25 10 Jun      19h     2 stops                       No info
# 3            23:30   5h 25m      1 stop                       No info
# 4            21:35   4h 45m      1 stop                       No info
# 5            11:25   2h 25m    non-stop                       No info
# 6     10:25 13 Mar  15h 30m      1 stop   In-flight meal not included
# 7     05:05 02 Mar   21h 5m      1 stop                       No info
# 8     10:25 13 Mar  25h 30m      1 stop   In-flight meal not included
# 9            19:15   7h 50m      1 stop                       No info
# 10           23:00  13h 15m      1 stop                       No info
# 11           22:55   2h 35m    non-stop                       No info
# 12           13:55   2h 15m    non-stop                       No info
# 13    09:20 10 May  12h 10m      1 stop   In-flight meal not included
# 14           19:50   2h 35m    non-stop                       No info
# 15    19:15 04 Mar  26h 35m     2 stops                       No info
# 16           13:15   4h 30m      1 stop                       No info
# 17    12:35 13 Jun  22h 35m      1 stop   In-flight meal not included
# 18    19:15 13 Jun      23h     2 stops                       No info
# 19    12:35 28 May  20h 35m      1 stop   In-flight meal not included
# 20           19:20   5h 10m      1 stop                       No info
# 21    13:20 19 Mar  15h 20m      1 stop                       No info
# 22           06:50   2h 50m    non-stop                       No info
# 23           21:50   2h 55m    non-stop                       No info
# 24    08:15 07 May  13h 20m      1 stop   In-flight meal not included
# 25    12:35 10 Jun  15h 10m     2 stops                       No info
# 26    03:35 02 Jun   5h 45m      1 stop                       No info
# 27           12:55   5h 55m      1 stop                       No info
# 28           12:35   2h 50m    non-stop                       No info
# 29           09:20   2h 15m    non-stop                       No info
# ...            ...      ...         ...                           ...
# 2641  01:30 10 May  11h 30m      1 stop                       No info
# 2642  12:35 22 May  13h 45m      1 stop   In-flight meal not included
# 2643  09:25 07 Jun  23h 40m     2 stops                       No info
# 2644         19:00  11h 30m      1 stop                       No info
# 2645  08:15 13 Mar   9h 20m      1 stop   In-flight meal not included
# 2646  04:25 20 May  29h 20m     2 stops                       No info
# 2647  08:55 02 May  16h 10m     2 stops                       No info
# 2648  00:20 02 Apr   3h 15m    non-stop                       No info
# 2649         08:35   2h 40m    non-stop  No check-in baggage included
# 2650  08:55 10 May   27h 5m     2 stops                       No info
# 2651         22:05  12h 30m      1 stop   In-flight meal not included
# 2652  13:15 13 Mar  14h 20m      1 stop                       No info
# 2653         22:35    6h 5m      1 stop   In-flight meal not included
# 2654  07:40 04 Mar  24h 40m      1 stop                       No info
# 2655         21:00   9h 20m      1 stop   In-flight meal not included
# 2656  09:20 13 May  12h 10m      1 stop   In-flight meal not included
# 2657         19:15  14h 20m      1 stop                       No info
# 2658  19:00 16 Jun  21h 10m      1 stop   In-flight meal not included
# 2659         12:35    7h 5m     2 stops   In-flight meal not included
# 2660         16:55       5m     2 stops                       No info
# 2661  04:25 29 Mar  33h 15m     2 stops                       No info
# 2662         15:25   1h 30m    non-stop                       No info
# 2663  07:45 13 May   8h 15m      1 stop                       No info
# 2664  01:30 16 Jun  10h 15m      1 stop                       No info
# 2665  00:15 22 Jun   1h 30m    non-stop  No check-in baggage included
# 2666  20:25 07 Jun  23h 55m      1 stop                       No info
# 2667         16:55   2h 35m    non-stop                       No info
# 2668  04:25 07 Mar   6h 35m      1 stop                       No info
# 2669         19:15  15h 15m      1 stop                       No info
# 2670         19:15  14h 20m      1 stop                       No info
#
#         Price  Date  Month  year
# 0      3897.0    24      3  2019
# 1      7662.0     1      5  2019
# 2     13882.0     9      6  2019
# 3      6218.0    12      5  2019
# 4     13302.0     1      3  2019
# 5      3873.0    24      6  2019
# 6     11087.0    12      3  2019
# 7     22270.0     1      3  2019
# 8     11087.0    12      3  2019
# 9      8625.0    27      5  2019
# 10     8907.0     1      6  2019
# 11     4174.0    18      4  2019
# 12     4667.0    24      6  2019
# 13     9663.0     9      5  2019
# 14     4804.0    24      4  2019
# 15    14011.0     3      3  2019
# 16     5830.0    15      4  2019
# 17    10262.0    12      6  2019
# 18    13381.0    12      6  2019
# 19    12898.0    27      5  2019
# 20    19495.0     6      3  2019
# 21     6955.0    21      3  2019
# 22     3943.0     3      4  2019
# 23     4823.0     1      5  2019
# 24     7757.0     6      5  2019
# 25    13292.0     9      6  2019
# 26     8238.0     1      6  2019
# 27     7682.0    15      5  2019
# 28     4668.0    18      6  2019
# 29     3687.0    15      6  2019
# ...       ...   ...    ...   ...
# 2641      NaN     9      5  2019
# 2642      NaN    21      5  2019
# 2643      NaN     6      6  2019
# 2644      NaN     3      6  2019
# 2645      NaN    12      3  2019
# 2646      NaN    18      5  2019
# 2647      NaN     1      5  2019
# 2648      NaN     1      4  2019
# 2649      NaN     6      5  2019
# 2650      NaN     9      5  2019
# 2651      NaN     6      6  2019
# 2652      NaN    12      3  2019
# 2653      NaN    18      5  2019
# 2654      NaN     3      3  2019
# 2655      NaN    24      6  2019
# 2656      NaN    12      5  2019
# 2657      NaN     6      6  2019
# 2658      NaN    15      6  2019
# 2659      NaN    15      6  2019
# 2660      NaN    12      3  2019
# 2661      NaN    27      3  2019
# 2662      NaN    21      5  2019
# 2663      NaN    12      5  2019
# 2664      NaN    15      6  2019
# 2665      NaN    21      6  2019
# 2666      NaN     6      6  2019
# 2667      NaN    27      3  2019
# 2668      NaN     6      3  2019
# 2669      NaN     6      3  2019
# 2670      NaN    15      6  2019
#
# [13354 rows x 13 columns]

# %%
big_df['Arrival_Time']=big_df['Arrival_Time'].str.split(' ').str[0]
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Dep_Time Arrival_Time Duration  \
# 9039  Air India  Delhi      Cochin   NaN    09:45        09:25  23h 40m
#
#      Total_Stops Additional_Info   Price  Date  Month  year
# 9039         NaN         No info  7480.0     6      5  2019

# %%
big_df['Total_Stops'] = big_df['Total_Stops'].fillna('1 stop')

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price, Date, Month, year]
# Index: []

# %%
big_df['Total_Stops'] = big_df['Total_Stops'].replace('non-stop','0 stop')

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Stops'] = big_df['Total_Stops'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    year Stops
# 0  2019     0
# 1  2019     2
# 2  2019     2
# 3  2019     1
# 4  2019     1

# %%
big_df=big_df.drop(['Total_Stops'], axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Date  Month  year Stops
# 0        01:10   2h 50m         No info   3897.0    24      3  2019     0
# 1        13:15   7h 25m         No info   7662.0     1      5  2019     2
# 2        04:25      19h         No info  13882.0     9      6  2019     2
# 3        23:30   5h 25m         No info   6218.0    12      5  2019     1
# 4        21:35   4h 45m         No info  13302.0     1      3  2019     1

# %%
big_df['Stops'] = big_df['Stops'].astype(int)
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Date  Month  year  Stops
# 0        01:10   2h 50m         No info   3897.0    24      3  2019      0
# 1        13:15   7h 25m         No info   7662.0     1      5  2019      2
# 2        04:25      19h         No info  13882.0     9      6  2019      2
# 3        23:30   5h 25m         No info   6218.0    12      5  2019      1
# 4        21:35   4h 45m         No info  13302.0     1      3  2019      1

# %%
big_df['Arrival_Hour']=big_df['Arrival_Time'].str.split(':').str[0]
big_df['Arrival_Minute']=big_df['Arrival_Time'].str.split(':').str[1]
big_df['Arrival_Hour'] = big_df['Arrival_Hour'].astype(int)
big_df['Arrival_Minute'] = big_df['Arrival_Minute'].astype(int)
big_df = big_df.drop(['Arrival_Time'], axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Additional_Info    Price  Date  Month  year  Stops  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019      0             1
# 1         No info   7662.0     1      5  2019      2            13
# 2         No info  13882.0     9      6  2019      2             4
# 3         No info   6218.0    12      5  2019      1            23
# 4         No info  13302.0     1      3  2019      1            21
#
#    Arrival_Minute
# 0              10
# 1              15
# 2              25
# 3              30
# 4              35

# %%
big_df['Departure_Hour']=big_df['Dep_Time'].str.split(':').str[0]
big_df['Departure_Minute']=big_df['Dep_Time'].str.split(':').str[1]
big_df['Departure_Hour'] = big_df['Departure_Hour'].astype(int)
big_df['Departure_Minute'] = big_df['Departure_Minute'].astype(int)
big_df = big_df.drop(['Dep_Time'], axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  year  Stops  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019      0             1
# 1         No info   7662.0     1      5  2019      2            13
# 2         No info  13882.0     9      6  2019      2             4
# 3         No info   6218.0    12      5  2019      1            23
# 4         No info  13302.0     1      3  2019      1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute
# 0              10              22                20
# 1              15               5                50
# 2              25               9                25
# 3              30              18                 5
# 4              35              16                50

# %%
big_df['Route_1']= big_df['Route'].str.split('→ ').str[0]
big_df['Route_2']= big_df['Route'].str.split('→ ').str[1]
big_df['Route_3']= big_df['Route'].str.split('→ ').str[2]
big_df['Route_4']= big_df['Route'].str.split('→ ').str[3]
big_df['Route_5']= big_df['Route'].str.split('→ ').str[4]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  year  Stops  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019      0             1
# 1         No info   7662.0     1      5  2019      2            13
# 2         No info  13882.0     9      6  2019      2             4
# 3         No info   6218.0    12      5  2019      1            23
# 4         No info  13302.0     1      3  2019      1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute Route_1 Route_2 Route_3  \
# 0              10              22                20    BLR      DEL     NaN
# 1              15               5                50    CCU     IXR     BBI
# 2              25               9                25    DEL     LKO     BOM
# 3              30              18                 5    CCU     NAG      BLR
# 4              35              16                50    BLR     NAG      DEL
#
#   Route_4 Route_5
# 0     NaN     NaN
# 1     BLR     NaN
# 2     COK     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
big_df['Price'].fillna((big_df['Price'].mean()), inplace=True)

# %%
big_df['Route_1'].fillna('None', inplace=True)
big_df['Route_2'].fillna('None', inplace=True)
big_df['Route_3'].fillna('None', inplace=True)
big_df['Route_4'].fillna('None', inplace=True)
big_df['Route_5'].fillna('None', inplace=True)

# %%
big_df = big_df.drop(['Route'], axis=1)
big_df = big_df.drop(['Duration'],axis=1)
big_df.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Date  Month  \
# 0       IndiGo  Banglore   New Delhi         No info   3897.0    24      3
# 1    Air India   Kolkata    Banglore         No info   7662.0     1      5
# 2  Jet Airways     Delhi      Cochin         No info  13882.0     9      6
# 3       IndiGo   Kolkata    Banglore         No info   6218.0    12      5
# 4       IndiGo  Banglore   New Delhi         No info  13302.0     1      3
#
#    year  Stops  Arrival_Hour  Arrival_Minute  Departure_Hour  \
# 0  2019      0             1              10              22
# 1  2019      2            13              15               5
# 2  2019      2             4              25               9
# 3  2019      1            23              30              18
# 4  2019      1            21              35              16
#
#    Departure_Minute Route_1 Route_2 Route_3 Route_4 Route_5
# 0                20    BLR      DEL    None    None    None
# 1                50    CCU     IXR     BBI      BLR    None
# 2                25    DEL     LKO     BOM      COK    None
# 3                 5    CCU     NAG      BLR    None    None
# 4                50    BLR     NAG      DEL    None    None

# %%
big_df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Additional_Info     0
# Price               0
# Date                0
# Month               0
# year                0
# Stops               0
# Arrival_Hour        0
# Arrival_Minute      0
# Departure_Hour      0
# Departure_Minute    0
# Route_1             0
# Route_2             0
# Route_3             0
# Route_4             0
# Route_5             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
big_df['Airline'] = encoder.fit_transform(big_df['Airline'])
big_df['Source'] = encoder.fit_transform(big_df['Source'])
big_df['Destination'] = encoder.fit_transform(big_df['Destination'])
big_df['Additional_Info'] = encoder.fit_transform(big_df['Additional_Info'])
big_df['Route_1'] = encoder.fit_transform(big_df['Route_1'])
big_df['Route_2'] = encoder.fit_transform(big_df['Route_2'])
big_df['Route_3'] = encoder.fit_transform(big_df['Route_3'])
big_df['Route_4'] = encoder.fit_transform(big_df['Route_4'])
big_df['Route_5'] = encoder.fit_transform(big_df['Route_5'])

# %%
big_df.head()
# Out:
#    Airline  Source  Destination  Additional_Info    Price  Date  Month  year  \
# 0        3       0            5                8   3897.0    24      3  2019
# 1        1       3            0                8   7662.0     1      5  2019
# 2        4       2            1                8  13882.0     9      6  2019
# 3        3       3            0                8   6218.0    12      5  2019
# 4        3       0            5                8  13302.0     1      3  2019
#
#    Stops  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0      0             1              10              22                20
# 1      2            13              15               5                50
# 2      2             4              25               9                25
# 3      1            23              30              18                 5
# 4      1            21              35              16                50
#
#    Route_1  Route_2  Route_3  Route_4  Route_5
# 0        0       13       24       12        4
# 1        2       25        1        3        4
# 2        3       32        4        5        4
# 3        2       34        3       12        4
# 4        0       34        8       12        4

# %% [markdown]
# # Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
big_df.shape
# Out:
# (13354, 18)

# %%
df_train = big_df[0:10683]
df_test = big_df[10683:]

# %%
X = df_train.drop(['Price'], axis=1)
y = df_train.Price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
model = SelectFromModel(Lasso(alpha=0.05,random_state=0))

# %%
model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.05, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False),
#         max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
selected_features = X_train.columns[(model.get_support())]
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Stops', 'Arrival_Hour', 'Arrival_Minute', 'Departure_Hour',
#        'Departure_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4',
#        'Route_5'],
#       dtype='object')

# %%
X_train = X_train.drop(['year'],axis=1)
X_test = X_test.drop(['year'],axis=1)

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start=100, stop=1200, num=12)]
max_features = ['auto','sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num=6)]
min_samples_split = [2,5,10,15,100]
min_samples_leaf = [1,2,5,10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
              'max_depth': max_depth,
              'min_samples_split': min_samples_split,
              'min_samples_leaf': min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid, scoring='neg_mean_squared_error', verbose=2, random_state=0)

# %%
rf_random.fit(X_train, y_train)
# Out:
# C:\Users\TEMP.DESKTOP-M8QKDFI\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=10, total=   4.6s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.9s remaining:    0.0s
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=10, total=   4.7s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=10, total=   4.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.7s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=  10.7s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30, total=  10.7s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=30

# %%
y_pred = rf_random.predict(X_test)

# %%
import seaborn as sns
sns.distplot(y_test-y_pred)

# %%
plt.scatter(y_test,y_pred)
